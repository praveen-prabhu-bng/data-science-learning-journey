# %% [markdown]
# #### Leaf Year Program
# Program to Identify if given Year is a Leap Year or Not

# %% [markdown]
# Determine if a year is a leap year using nested condition statement
# Logic Flow
# - If the year is not divisible by 4 → ❌ Not a leap year.
# - If divisible by 4 but not divisible by 100 → ✅ Leap year.
# - If divisible by 100 but not divisible by 400 → ❌ Not a leap year.
# - If divisible by 400 → ✅ Leap year.

# %%
year=int(input("Enter the year"))

if year%4==0: # Step 1: Is the year divisible by 4?
    if year%100==0: # Step 2: If yes, is it also divisible by 100?
        if year%400==0: # Step 3: If yes, is it also divisible by 400?
            print(year,"is a leap year") # Divisible by 400 → Leap year
        else:
            print(year,"is not a leap year") # Divisible by 100 but not 400 → Not leap year
    else:
        print(year,"is a leap year") # Divisible by 4 but not 100 → Leap year

else:
    print(year,"is not a leap year") # Not divisible by 4 → Not leap year
# Out:
# Enter the year 2028
# 2028 is a leap year

# %% [markdown]
# #### Simple Calculator program

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform the requested operation
if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation."

print("Result:", result)
# Out:
# Enter first number:  34
# Enter second number:  235
# Enter operation (+, -, *, /):  /
# Result: 0.14468085106382977

# %% [markdown]
# #### Employee Bonus Calculation
# Calculate an employee's bonus based on their performance rating and years of service.

# %%
# Employee bonus calculation

# Take user input
years_of_service = int(input("Enter years of service: "))
performance_rating = float(input("Enter performance rating (1.0 to 5.0): "))

# Determine bonus percentage
if performance_rating >= 4.5:
    if years_of_service > 10:
        bonus_percentage = 20
    elif years_of_service > 5:
        bonus_percentage = 15
    else:
        bonus_percentage = 10
elif performance_rating >= 3.5:
    if years_of_service > 10:
        bonus_percentage = 15
    elif years_of_service > 5:
        bonus_percentage = 10
    else:
        bonus_percentage = 5
else:
    bonus_percentage = 0

# Calculate bonus amount
salary = float(input("Enter current salary: "))
bonus_amount = salary * bonus_percentage / 100

print("Bonus Amount: ${:.2f}".format(bonus_amount))# ":" introduces a format specification. Everything after ":" tells Python how to display the value.
# - :.2f means: f → format as a floating-point number , .2 → show 2 digits after the decimal point
# Hence ":" says “apply formatting rules to this value.” and ".2f" says “round to 2 decimal places as a float.
# .format(bonus_amount) → This takes the value of bonus_amount and inserts it into the placeholder.
# Out:
# Enter years of service:  23
# Enter performance rating (1.0 to 5.0):  4
# Enter current salary:  100000
# Bonus Amount: $15000.00

# %% [markdown]
# #### User Login System
# A simple user login system that checks the username and password.

# %%
# User login system

# Predefined username and password
stored_username = "admin"
stored_password = "password123"

# Take user input
username = input("Enter username: ")
password = input("Enter password: ")

# Check login credentials
if username == stored_username:
    if password == stored_password:
        print("Login successful!")
    else:
        print("Incorrect password.")
else:
    print("Username not found.")
# Out:
# Enter username:  admin
# Enter password:  password12
# Incorrect password.

# %% [markdown]
# #### Print a triangle (or pyramid) of stars

# %%
size = int(input("Enter the triangle Length:"))
for i in range(size):
    for j in range(size-i):
        print("",end=" ")
    for k in range(i+1) :
        print("*",end="")
    for m in range(k-1):
        print("*", end="")
    print()
# Out:
# Enter the triangle Length: 10
#           *
#          **
#         ****
#        ******
#       ********
#      **********
#     ************
#    **************
#   ****************
#  ******************

# %%
## solution 2
n = 20
for i in range(n):
    print(" "*(n-i),end='')
    for j in range(i*2+1):
        print("*",end="")
    print()
# Out:
#                     *
#                    ***
#                   *****
#                  *******
#                 *********
#                ***********
#               *************
#              ***************
#             *****************
#            *******************
#           *********************
#          ***********************
#         *************************
#        ***************************
#       *****************************
#      *******************************
#     *********************************
#    ***********************************
#   *************************************
#  ***************************************
