# %% [markdown]
# #### Regular Image Attach process

# %% [markdown]
# ![](DS_Images/DS_Classification.png)

# %% [markdown]
# #### Repo Root path - Image Attach process

# %% [markdown]
# ![](Topics/2.0-Data_Structures/DS_Images/DS_Classification.png)

# %% [markdown]
# ### Use a Raw GitHub URL

# %% [markdown]
# ![](https://raw.githubusercontent.com/praveen-prabhu-bng/data-science-learning-journey/main/Topics/2.0-Data_Structures/DS_Images/DS_Classification.png)

# %% [markdown]
# ### HTML img tag

# %% [markdown]
# <img src="Topics/2.0-Data_Structures/DS_Images/DS_Classification.png" width="600"/>

# %% [markdown]
# ## Claude try

# %% [markdown]
# ![](Topics/2.0-Data_Structures/DS_Images/DS_Classification.png)

# %% [markdown]
# ## CLaude raw GitHub URL

# %% [markdown]
# ![](https://raw.githubusercontent.com/praveen-prabhu-bng/data-science-learning-journey/main/Topics/2.0-Data_Structures/DS_Images/DS_Classification.png)
